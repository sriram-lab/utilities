# %% [markdown]
# <a href="https://colab.research.google.com/github/sriram-lab/utilities/blob/master/Metabolomics_mapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Metabolomics parser

# %% [markdown]
# `metabolomics-parser.py` uses the common metabolite names in a metabolomics dataset and maps them to standard
# metabolite identifiers in established databases. This is used for mapping metabolites to constraint-based metabolic
# models (sbml-based namespaces only).

# %% [markdown]
# **Author:** Scott Campit

# %%
import sys, os
import re
import pandas as pd
import numpy as np

# Install dependencies
# !pip3 install pubchempy
# !pip3 install cobra
# !pip3 install lxml
# !pip3 install xlsxwriter
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pubchempy in /home/scampit/.local/lib/python3.7/site-packages (1.0.4)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: cobra in /home/scampit/.local/lib/python3.7/site-packages (0.17.1)
# Requirement already satisfied: swiglpk in /home/scampit/.local/lib/python3.7/site-packages (from cobra) (4.65.1)
# Requirement already satisfied: ruamel.yaml>=0.16 in /home/scampit/.local/lib/python3.7/site-packages (from cobra) (0.16.6)
# Requirement already satisfied: depinfo in /home/scampit/.local/lib/python3.7/site-packages (from cobra) (1.5.3)
# Requirement already satisfied: numpy>=1.13 in /home/scampit/.local/lib/python3.7/site-packages (from cobra) (1.18.1)
# Requirement already satisfied: python-libsbml-experimental==5.18.0 in /home/scampit/.local/lib/python3.7/site-packages (from cobra) (5.18.0)
# Requirement already satisfied: optlang>=1.4.2 in /home/scampit/.local/lib/python3.7/site-packages (from cobra) (1.4.4)
# Requirement already satisfied: six in /home/scampit/.local/lib/python3.7/site-packages (from cobra) (1.14.0)
# Requirement already satisfied: future in /home/scampit/.local/lib/python3.7/site-packages (from cobra) (0.18.2)
# Requirement already satisfied: pandas>=0.17.0 in /home/scampit/.local/lib/python3.7/site-packages (from cobra) (0.25.3)
# Requirement already satisfied: ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.8" in /home/scampit/.local/lib/python3.7/site-packages (from ruamel.yaml>=0.16->cobra) (0.2.0)
# Requirement already satisfied: pipdeptree>=0.13.2 in /home/scampit/.local/lib/python3.7/site-packages (from depinfo->cobra) (0.13.2)
# Requirement already satisfied: sympy>=1.0.0 in /home/scampit/.local/lib/python3.7/site-packages (from optlang>=1.4.2->cobra) (1.5.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /home/scampit/.local/lib/python3.7/site-packages (from pandas>=0.17.0->cobra) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /home/scampit/.local/lib/python3.7/site-packages (from pandas>=0.17.0->cobra) (2019.3)
# Requirement already satisfied: pip>=6.0.0 in /home/scampit/.local/lib/python3.7/site-packages (from pipdeptree>=0.13.2->depinfo->cobra) (20.1.1)
# Requirement already satisfied: mpmath>=0.19 in /home/scampit/.local/lib/python3.7/site-packages (from sympy>=1.0.0->optlang>=1.4.2->cobra) (1.1.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: lxml in /home/scampit/.local/lib/python3.7/site-packages (4.4.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: xlsxwriter in /home/scampit/.local/lib/python3.7/site-packages (1.2.8)

# %% [markdown]
# ## Query the PubChem database for metabolite name synoynms that match with the metabolomics

# %% [markdown]
# `queryPubChem` maps the metabolite name from a Pandas dataframe in the `Compound Method` column and extracts synoynms from several databases using the PubChem API.
#
# **INPUTS:**
#   * `data:` A Pandas dataframe of the metabolomics dataframe with common metabolite identifiers.
#     * **NOTE:** Common metabolite names need to be under the `Compound Method` column name in the Pandas dataframe.
#   * `filename:` A string denoting the path to the metabolomics dataset.
#   * `sheet:` A string denoting the sheet name from the metabolomics file. By default, the sheet name that is read in is `Sheet1`.
#
# **OUTPUTS:**
#   * `all_compoounds:` A Pandas series containing the all metabolite synoynms as a single column.
#   * `queryList:` A list containing all metabolite synoynms.

# %%
def queryPubChem(data, filename='', sheet='Sheet1'):
    """
    queryPubChem maps the metabolite name from a pandas Dataframe in the 'Compound Method' column and extracts
    synoynms from several databases using the PubChem API.
    :param data:           A Pandas Dataframe of the metabolomics dataframe with the common metabolite identifiers
                           under the 'Compound Method' column
    :return all_compounds: A Pandas Dataframe from the PubChem API containing the metabolite map. This dataframe is
                           saved as a .csv file.
    :return queryList:     A string with semicolon delimters to be fed into a REST-API
    """
    import pubchempy as pcp

    # Split 'Compound Method' column by the '/' regex and clean up some data
    data = data.drop('Compound Method', axis=1).join(data['Compound Method']
                                                 .str.split('/', expand=True)
                                                 .stack().reset_index(level=1, drop=True)
                                                 .rename('Metabolite'))
    data['Metabolite'] = data['Metabolite'].str.lower()
    pubChemQuery = data['Metabolite'].tolist()

    # Mine the PubChem database for synonyms
    all_compounds = []
    print("Mapping metabolite names to PubChem database for synonym matching and ID retrieval.")
    for metabolite in pubChemQuery:
        try:
            df = pcp.get_substances(identifier=metabolite,
                                    namespace='name',
                                    as_dataframe=True)
            df['Name'] = metabolite
            df = df.applymap(str)
            all_compounds.append(df)

        except (KeyError, TimeoutError, pcp.TimeoutError):
            continue

    # Explode synonyms column
    all_compounds = pd.concat(all_compounds)
    all_compounds = all_compounds.drop('synonyms', axis=1).join(all_compounds['synonyms']
                                                              .str.split(',', expand=True)
                                                              .stack().reset_index(level=1, drop=True)
                                                              .rename('synonyms'))
    
    return all_compounds

# %% [markdown]
# ## Query MetaboAnalyst database to get matching systematic identifiers using all synonyms

# %% [markdown]
# `queryMetaboAnalyst` takes in the filepath corresponding to the metabolomics data and uses the first column as metabolite names in the file.
#
# **NOTE:** This function uses the `queryPubChem` function, and needs the first column in the metabolomics data file to be named `Compound Method`.
#
# **INPUTS:**
#   * `filename:` A string denoting the path to the metabolomics dataset.
#   * `sheet:` A string denoting the sheet name from the metabolomics file. By default, the sheet name that is read in is `Sheet1`.
#
# **OUTPUT:**
#   * `data:` A Pandas dataframe containing all systematic metabolite IDs

# %%
def queryMetaboAnalyst(filename='', sheet='Sheet1', synmatch=True):
    """
    queryMetaboAnalyst takes the file (currently only written for csv files),
    and uses the first column as metabolite names in the file. 
    
    The metabolite names are queried using MetaboAnalyst. The output is a metabolite map consisting of
    several different identifiers for the given metabolite.

    INPUTS:
    :param   filename: A string denoting the path to a text delimited or Excel file containing the metabolomics data
    :param   sheet:    A string denoting the tab name to read in
    :param   synmatch: A boolean flag determining whether to perform synonym matching or not

    OUTPUT:
    :return: data:     A Pandas dataframe with a metabolite map containing several different metabolite identifiers
    """

    import requests
    import json

    print('Mapping metabolomics data to additional identifiers')
    if os.path.splitext(filename)[1] is '.xls' or 'xlsx':
        fileData = pd.read_excel(filename, sheet_name=sheet)
    else:
        fileData = pd.read_csv(filename)
    
    # Load from Google Drive
    #wb = gc.open_by_url(filename)
    #wks = wb.worksheet(sheet)
    #data = wks.get_all_values()
    #fileData = pd.DataFrame(data)
    #header = fileData.iloc[0] 
    #fileData = fileData[1:] 
    #fileData.columns = header

    patterns = ["[", "]", "'", '"']
    if synmatch is True:
        # Get synonyms of each metabolite from PubChem
        all_compounds = queryPubChem(fileData)
        # Clean up regexes and get unique compounds
        for p in patterns:
            all_compounds['synonyms'] = all_compounds['synonyms'].str.replace(p, '')
            all_compounds['synonyms'] = all_compounds['synonyms'].str.strip()
        all_compounds['synonyms'] = all_compounds['synonyms'].str.lower()
        all_compounds['Compound Method'] = all_compounds['synonyms']
    else:
        all_compounds = fileData
        for p in patterns:
            all_compounds['Compound Method'] = all_compounds['Compound Method'].str.replace(p, '')
            all_compounds['Compound Method'] = all_compounds['Compound Method'].str.strip()
        all_compounds['Compound Method'] = all_compounds['Compound Method'].str.lower()

    queryList = ';'.join(all_compounds['Compound Method'].unique())

    # Query metaboAnalyst for additional database identifiers
    queryDict = {"queryList" : queryList,
             "inputType" : "name"}
    metabolites = json.dumps(queryDict)

    # Query MetaboAnalyst using data set metabolites
    url = "http://api.xialab.ca/mapcompounds"
    headers = {
        'Content-Type': "application/json",
        'cache-control': "no-cache",
    }
    response = requests.request("POST", url, data=metabolites, headers=headers).json()
    data = pd.DataFrame(response)

    identifiers = ['hmdb_id', 'kegg_id', 'pubchem_id', 'chebi_id', 'chebi_id', 'metlin_id']
    for id in identifiers:
        data[id] = data[id].replace('-', np.nan)
        data[id] = data[id].astype(str)
    print('MetaboAnalyst query done!')

    return data

# %% [markdown]
# ## Extracting metabolite identifiers from RECON1

# %% [markdown]
# `mapMetabolicModel` takes in a metabolic model (xml format only), and parses the ChEBI, HMDBidentifiers in the map.
#
# **NOTE:** Currently only tested with RECON1 - xml namespaces will change depending on sbml specifications per metabolic models.
#
# **INPUT:**
#   * `model:` A string describing the path to the COBRA metabolic model file (`.xml` or `.sbml` file types supported only.
#
# **OUTPUT:**
#   * `modelMap:` A Pandas dataframe containing the metabolite identifiers for each metabolite in the metabolic model.

# %%
def mapMetabolicModel(model):
    """
    mapMetabolicModel takes in a metabolic model (xml format only), and parses the
    identifiers in the map. 
    
    Currently only tested with RECON1 - xml namespaces will change depending on metabolic models.

    :param  model:    A string describing the path to the metabolic model file (`.xml` or `.sbml` file types supported only.
    :return modelMap: A Pandas dataframe containing metabolite identifiers from the metabolic model
    """

    from lxml import etree
    print('Parsing metabolic model to get metabolite and associated identifiers')
    context = etree.parse(model)

    # Namespaces for different databases in the sbml models
    chebi_pattern = re.compile(r'.*http://identifiers.org/chebi/CHEBI:(\d+)')
    hmdb_pattern = re.compile(r'.*http://identifiers.org/hmdb/HMDB(\d+)')
    kegg_pattern = re.compile(r'.*http://identifiers.org/kegg.compound/C(\d+)')

    modelMap = pd.DataFrame()
    for metabolite in context.iter(tag='{http://www.sbml.org/sbml/level3/version1/core}species'):
        name = metabolite.get("name")
        bigg = metabolite.get("metaid")
        for element in metabolite.iter():
            if element.tag == '{http://www.w3.org/1999/02/22-rdf-syntax-ns#}li':
                content = etree.tostring(element)
                content_string = content.decode("utf-8")

                metabolite_name = []
                chebi = []
                hmdb = []
                kegg = []

                # Get metabolite identifiers for CHEBI, HMDB and KEGG
                metabolite_name.append(name)
                metabolite_name = str(metabolite_name).replace(
                    '[', '').replace(']', '')

                if re.match(chebi_pattern, content_string):
                    chebi_num = re.findall(chebi_pattern, content_string)
                    chebi.append(chebi_num)
                else:
                    chebi.append(np.nan)
                chebi = str(chebi).replace('[', '').replace(']', '')

                if re.match(hmdb_pattern, content_string):
                    hmdb_num = re.findall(hmdb_pattern, content_string)
                    hmdb_num = ["HMDB" + h for h in hmdb_num]
                    hmdb.append(hmdb_num)
                else:
                    hmdb.append(np.nan)
                hmdb = str(hmdb).replace('[', '').replace(']', '')

                if re.match(kegg_pattern, content_string):
                    kegg_num = re.findall(kegg_pattern, content_string)
                    kegg_num = ["C" + k for k in kegg_num]
                    kegg.append(kegg_num)
                else:
                    kegg.append(np.nan)
                kegg = str(kegg).replace('[', '').replace(']', '')

                # Format stuff correctly before saving
                modelMap = modelMap.append({'Metabolite':metabolite_name,
                                            'BIGG':bigg, 'HMDB':hmdb,
                                            'CHEBI':chebi, 'KEGG':kegg},
                                            ignore_index=True)
        element.clear()
    
    for col in modelMap:
        modelMap[col] = modelMap[col].astype(str)
        modelMap[col] = modelMap[col].str.replace("'", "")
    print("Metabolic map complete")
    return modelMap

# %% [markdown]
# ## Match model identifiers with the dataset

# %% [markdown]
# `matchModelAndData` uses the identifiers from the metabolomics data and the model to find matches between them.
#
# **INPUTS:**
#   * `data:` A Pandas dataframe containing the matched metabolite identifiers queried from MetaboAnalyst.
#   * `modelMap:` A Pandas dataframe containing the mapped metabolite names from the COBRA metabolic model.
#
# **OUTPUT:**
#   * `mergedModelDataMap:` A Pandas dataframe of the merged map between the metabolomics data and the COBRA metabolic model.

# %%
def matchModelAndData(data, modelMap):
    """
    matchModelAndData uses the identifiers from the metabolomics data and the model
    to find matches between them.

    :param  data:               A Pandas dataframe containing data queried from MetaboAnalyst.
    :param  modelMap:           A Pandas dataframe queried from mapping the metabolite names to the COBRA metabolic
                                model.
    :return mergedModelDataMap: A Pandas dataframe of the merged map between the metabolomics data and the
                                metabolic model.
    """

    print('Match metabolomics identifiers and model identifiers by ChEBI and KEGG IDs')
    chebi = pd.merge(modelMap, data, left_on='CHEBI', right_on='chebi_id')
    #chebi = chebi[np.isfinite(chebi['CHEBI'])]
    chebi = chebi[["Metabolite", "query", "BIGG", "CHEBI"]]
    #print(chebi)
    
    kegg = pd.merge(modelMap, data, left_on='KEGG', right_on='kegg_id')
    #kegg = kegg[pd.notnull(kegg['KEGG'])]
    kegg = kegg[['Metabolite', 'query', 'BIGG', 'KEGG']]
    #print(kegg)
    mergedModelDataMap = pd.merge(chebi, kegg,
                                  how='inner', on=['Metabolite', 'query', 'BIGG'])
    mergedModelDataMap = mergedModelDataMap.drop_duplicates('BIGG', keep='first')
    #print(mergedModelDataMap)
    print("Found matching metabolites based on ChEBI and KEGG identities!")
    return mergedModelDataMap

# %% [markdown]
# ## Map metabolite positions from metabolic model to the dataset

# %% [markdown]
# `mapMetabolitePositionsInModel` gets the metabolite positions using the `cobrapy` library.
#
# **INPUTS:**
#   * `mergedModelDataMap:` A Pandas dataframe of the merged map between the metabolomics data and the COBRA metabolic model.
#   * `model:` A string denoting the path to the COBRA metabolic model ()
#
# **OUTPUT:**
#   * `PositionModel:` A Pandas dataframe containing the positions for each metabolite in the metabolic model.

# %%
def mapMetabolitePositionsInModel(mergedModelDataMap, model):
    """
    mapMetabolitePositionsInModel gets the metabolite positions using the cobrapy library.

    :param  mergedModelDataMap: A Pandas dataframe of the merged map between the metabolomics data and the metabolic
                                model.
    :param  model:              A string denoting the path to the metabolic model (`.xml` or `.sbml` file types supported only.
    :return PositionModel:      A Pandas dataframe containing the positions for each metabolite in the metabolic model.
    """

    import cobra
    print("Mapping metabolite positions in metabolic model")
    bigg_ids = mergedModelDataMap['BIGG'].replace('M_', '')
    bigg_ids = list(bigg_ids)
    biggRxn = pd.DataFrame()
    mdl = cobra.io.read_sbml_model(model)

    for index, met in enumerate(mdl.metabolites):
        if any(str(met) in m for m in bigg_ids):
            biggRxn = biggRxn.append(pd.DataFrame({"Position": index,
                                                   "Metabolite": [met]}
                                                  ), ignore_index=True)

    biggRxn['Metabolite'] = biggRxn['Metabolite'].astype(str)
    biggRxn["Compartment"] = biggRxn["Metabolite"].str.rsplit('_').str[-1]
    biggRxn["Metabolite"] = biggRxn["Metabolite"].str.split('_').str[0]

    biggRxn = biggRxn.pivot_table(index='Metabolite',
                            columns='Compartment',
                            values='Position',
                            aggfunc='mean', fill_value=0)

    mergedModelDataMap['BIGG'] = mergedModelDataMap['BIGG'].str.split('_', n=1).str[-1]
    mergedModelDataMap['BIGG'] = mergedModelDataMap['BIGG'].str.rsplit('_', n=1).str[0]
    mergedModelDataMap = mergedModelDataMap.drop(['CHEBI', 'KEGG', 'Metabolite'], axis=1)
    mergedModelDataMap = mergedModelDataMap.drop_duplicates('BIGG', keep='first')

    PositionModel = pd.merge(biggRxn, mergedModelDataMap,
                              left_index=True, right_on='BIGG')
    PositionModel = PositionModel.drop(['BIGG'], axis=1)
    PositionModel = PositionModel.set_index(['query'])

    print('Mapped metabolite positions in metabolic model to metabolite name')
    return PositionModel

# %% [markdown]
# ## Construct the final dataset used for Dynamic Flux Analysis from Google Drive

# %% [markdown]
# `constructFinalDataset` merges the array of metabolite positions and the file name together. It automatically outputs an Excel file, ready for piping into DFA.
#
# **INPUTS:**
#   * `PositionModel:` A Pandas dataframe containing the metabolite positions in the metabolic model.
#   * `filename:` A string denoting the path of the metabolomics data.
#   * `sheet:` A string denoting the sheet name from the Excel sheet, if the file specified is an Excel file.
#
# **OUTPUT:**
#   * An Excel sheet containing the mapped data.

# %%
def constructFinalDataset(PositionModel, filename, sheet='Sheet1'):
    """
    constructFinalDataset merges the array of metabolite positions and the file name together.
    It automatically outputs an Excel file, ready for piping into DFA.
    
    :param  PositionModel: A Pandas dataframe containing the metabolite positions in the metabolic model.
    :param  filename:      A string denoting the path of the metabolomics data.
    :return df:            A Pandas dataframe containing the metabolomics data that intersects with the metabolic
                           model and the metabolite positions in the metabolomic model.
    """
    
    print("Merging metabolomics data to model map")
    if os.path.splitext(filename)[1] is '.xls' or 'xlsx':
        fileData = pd.read_excel(filename, sheet_name=sheet)
    else:
        fileData = pd.read_csv(filename)
    
    # Load from Google Drive
    #wb = gc.open_by_url(filename)
    #wks = wb.worksheet(sheet)
    #data = wks.get_all_values()
    #fileData = pd.DataFrame(data)
    #header = fileData.iloc[0] 
    #fileData = fileData[1:] 
    #fileData.columns = header

    # Clean up regexes
    all_compounds = fileData
    patterns = ["[", "]", "'", '"']
    for p in patterns:
        all_compounds['Compound Method'] = all_compounds['Compound Method'].str.replace(p, '')
        all_compounds['Compound Method'] = all_compounds['Compound Method'].str.strip()
    all_compounds['Compound Method'] = all_compounds['Compound Method'].str.lower()

    df = pd.merge(PositionModel, fileData,
                  left_index=True, right_on='Compound Method',
                  how='inner') 
    print("Finished merging metabolomics data to model map!")
    return df

# %% [markdown]
# Now that we have a function that uses all of the accessory functions written above, let's get our final metabolomics dataset from the ME1 dataset. First we need to mount our Google Drive account.

# %%
# This bit of code adds your Google Drive files into /content
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-278dabf14523> in <module>
#       1 # This bit of code adds your Google Drive files into /content
# ----> 2 from google.colab import drive
#       3 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google.colab'

# %% [markdown]
# Now let's install some stuff that let's us read in Google sheets.

# %%
# Install gspread if you haven't already
#!pip install --upgrade -q gspread
import gspread
from google.colab import auth
from oauth2client.client import GoogleCredentials
auth.authenticate_user()
gc = gspread.authorize(GoogleCredentials.get_application_default())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-1f9562aa5b37> in <module>
#       4 #from google.colab import auth
#       5 from oauth2client.client import GoogleCredentials
# ----> 6 auth.authenticate_user()
#       7 gc = gspread.authorize(GoogleCredentials.get_application_default())
#
# NameError: name 'auth' is not defined

# %% [markdown]
# Next, let's call our files into the function.

# %%
# GOT1 Data
model = r'/content/drive/My Drive/DFA CV and NaN Filters/RECON1/RECON1.xml'
name = r'https://docs.google.com/spreadsheets/d/1LOSiuXWEC4lFEZQOYRkktXMJpZ_pef_X9YE8592-9EI/edit#gid=0'

# ME1 Data
#model = r'/content/drive/My Drive/work/data/MetabolicModels/RECON1/RECON1.xml' 
#name = r'https://docs.google.com/spreadsheets/d/15Ma7bbSP1B6j6U9SDN6lrxwR3jIv6o6xRAYfnKGCUhk/edit?usp=sharing'

# %% [markdown]
# Finally, we can run our parser.

# %%
import gspread
from google.colab import auth
from oauth2client.client import GoogleCredentials
from googleapiclient import discovery

# Load the google sheet using a shared URL
wb = gc.open_by_url(name)

# This gets the sheet names, skips the first sheet (README), and finally stores 
# everything into a list.
tmp = wb.worksheets()
tmp = tmp[1:]
sheetNames = [i.title for i in tmp]

# Create a spreadsheet that will save all of the data
writer = pd.ExcelWriter('ME1_mapped_metabolomics.xlsx', engine='xlsxwriter')

# Parts of the parser that will take a long time, especially if `synmatch` is True
modelMap = mapMetabolicModel(model)
data = queryMetaboAnalyst(filename=name, sheet=sheetNames[0], synmatch=False)
mergedModelDataMap = matchModelAndData(data, modelMap)
PositionModel = mapMetabolitePositionsInModel(mergedModelDataMap, model)

# Save multiple sheets
for sht in sheetNames:
    df = constructFinalDataset(PositionModel, name, sht)
    df.to_excel(writer, sheet_name=sht, index=False)
    writer.save()
# Out:
# Mapping metabolomics data to additional identifiers
# Mapping metabolite names to PubChem database for synonym matching and ID retrieval.
#                              source_id  ...              Name
# sid                                     ...
# 53787130                       C058118  ...  2-deoxyadenosine
# 162088429                       102392  ...  2-deoxyadenosine
# 342500535                   WU050235CA  ...  2-deoxyadenosine
# 348274250                  HMDB0000101  ...  2-deoxyadenosine
# 383326151                 NSZB-A110030  ...  2-deoxyadenosine
# 404876780                   LQT-B18165  ...  2-deoxyadenosine
# 121474                           83258  ...  2-deoxyadenosine
# 427201                          141848  ...  2-deoxyadenosine
# 428054                          143510  ...  2-deoxyadenosine
# 250013057  OLXZPDWKRNYJJZ-UHFFFAOYSA-N  ...  2-deoxyadenosine
#
# [10 rows x 5 columns]
#           source_id  ...             Name
# sid                  ...
# 117529240  AC1Q52OM  ...  2-deoxycytidine
#
# [1 rows x 5 columns]
#                                source_id  ...                           Name
# sid                                       ...
# 8605                              C06369  ...  2-deoxy-d-glucose 6-phosphate
# 242084165                    CHEBI:84756  ...  2-deoxy-d-glucose 6-phosphate
# 312247106                          68751  ...  2-deoxy-d-glucose 6-phosphate
# 404760839    UQJFZAAGZAYVKZ-CERMHHMHSA-N  ...  2-deoxy-d-glucose 6-phosphate
# 22395938                     CHEBI:16043  ...  2-deoxy-d-glucose 6-phosphate
# 385657082                      Q27098347  ...  2-deoxy-d-glucose 6-phosphate
# 386493554                      Q27098347  ...  2-deoxy-d-glucose 6-phosphate
# 57389821   2-DEOXY-D-GLUCOSE-6-PHOSPHATE  ...  2-deoxy-d-glucose 6-phosphate
# 242084166                    CHEBI:84760  ...  2-deoxy-d-glucose 6-phosphate
#
# [9 rows x 5 columns]
#                              source_id  ...              Name
# sid                                     ...
# 84874                            22837  ...  2-deoxyguanosine
# 250033392  YKBGVTZYEHREMT-UHFFFAOYSA-N  ...  2-deoxyguanosine
# 348274240                  HMDB0000085  ...  2-deoxyguanosine
# 373251941                  Amb21855752  ...  2-deoxyguanosine
# 387179851  YKBGVTZYEHREMT-UHFFFAOYSA-N  ...  2-deoxyguanosine
# 404876784                   LQT-B18169  ...  2-deoxyguanosine
#
# [6 rows x 5 columns]
#                                 source_id  ...            Name
# sid                                        ...
# 252053708                         BD74341  ...  2-deoxyinosine
# 312695817                           T1709  ...  2-deoxyinosine
# 319105792  ToxPlanet-ODkwLTM4LTA2NTA1OA==  ...  2-deoxyinosine
# 117613662                        AC1Q77TN  ...  2-deoxyinosine
#
# [4 rows x 5 columns]
#                                 source_id  ...                       Name
# sid                                        ...
# 76573997                           150629  ...  2-deoxyribose 5-phosphate
# 135107203                      0007685509  ...  2-deoxyribose 5-phosphate
# 315787909                  DTXSID00227659  ...  2-deoxyribose 5-phosphate
# 319168008  ToxPlanet-NzY4NS01MC05MTUwNjI5  ...  2-deoxyribose 5-phosphate
# 348274995                     HMDB0001031  ...  2-deoxyribose 5-phosphate
# 387114502     KKZFLSZAWCYPOC-VPENINKCSA-N  ...  2-deoxyribose 5-phosphate
# 76573996                          3340485  ...  2-deoxyribose 5-phosphate
# 250135267     KKZFLSZAWCYPOC-UOWFLXDJSA-N  ...  2-deoxyribose 5-phosphate
# 387114501     KKZFLSZAWCYPOC-UHFFFAOYSA-N  ...  2-deoxyribose 5-phosphate
# 404760759     KKZFLSZAWCYPOC-PYHARJCCSA-N  ...  2-deoxyribose 5-phosphate
#
# [10 rows x 5 columns]
#                              source_id  ...            Name
# sid                                     ...
# 3809                            C00526  ...  2-deoxyuridine
# 650425                          113822  ...  2-deoxyuridine
# 85165120                    bmse000320  ...  2-deoxyuridine
# 163808484                    KSC491M3N  ...  2-deoxyuridine
# 223743557  MXHRCPNRJAMMIM-SHYZEUOFSA-N  ...  2-deoxyuridine
# 312695923                        T1721  ...  2-deoxyuridine
# 404876787                   LQT-B18172  ...  2-deoxyuridine
# 85466                            23615  ...  2-deoxyuridine
# 841963                           12037  ...  2-deoxyuridine
# 341233015           16047413-387720027  ...  2-deoxyuridine
# 363666351  MXHRCPNRJAMMIM-UHFFFAOYSA-N  ...  2-deoxyuridine
# 346695565                   LN00196594  ...  2-deoxyuridine
#
# [12 rows x 5 columns]
#                              source_id  ...                   Name
# sid                                     ...
# 841567                            1084  ...  2-isopropylmalic acid
# 8145547                    CHEBI:28635  ...  2-isopropylmalic acid
# 144080983                   bmse000982  ...  2-isopropylmalic acid
# 160963344                   bmse001025  ...  2-isopropylmalic acid
# 162234265                       140020  ...  2-isopropylmalic acid
# 162270535                   ACMC-1BNF9  ...  2-isopropylmalic acid
# 204408660                    TC-170504  ...  2-isopropylmalic acid
# 250135159  BITYXLXUCSKTJS-UHFFFAOYSA-N  ...  2-isopropylmalic acid
# 332873562                     J-018719  ...  2-isopropylmalic acid
# 341164263           12043786-749421667  ...  2-isopropylmalic acid
# 342523363                   WB411417ST  ...  2-isopropylmalic acid
# 363602630  BITYXLXUCSKTJS-UHFFFAOYSA-N  ...  2-isopropylmalic acid
# 385642630                    Q15426256  ...  2-isopropylmalic acid
# 386478916                    Q15426256  ...  2-isopropylmalic acid
# 387074477  BITYXLXUCSKTJS-UHFFFAOYSA-N  ...  2-isopropylmalic acid
# 404754090  BITYXLXUCSKTJS-UHFFFAOYSA-N  ...  2-isopropylmalic acid
# 5516                            C02504  ...  2-isopropylmalic acid
# 11533722                   CHEBI:35128  ...  2-isopropylmalic acid
# 348274483                  HMDB0000402  ...  2-isopropylmalic acid
# 363664016  BITYXLXUCSKTJS-ZETCQYMHSA-N  ...  2-isopropylmalic acid
# 363666199  RNQHMTFBUSSBJQ-UHFFFAOYSA-N  ...  2-isopropylmalic acid
# 57389290        3-HYDROXYPHENYLACETATE  ...  3-hydroxyphenylacetic acid
#
# [72 rows x 5 columns]
#                              source_id  ...                 Name
# sid                                     ...
# 70220                             3787  ...  3-indoleacetic acid
# 604352                          009893  ...  3-indoleacetic acid
# 841420                             679  ...  3-indoleacetic acid
# 47193742                  MLS001066408  ...  3-indoleacetic acid
# 49857435                       LS-7456  ...  3-indoleacetic acid
# 56320741                  MLS001332400  ...  3-indoleacetic acid
# 56322628                  MLS001332399  ...  3-indoleacetic acid
# 56422762                  MLS001331664  ...  3-indoleacetic acid
# 76715699                       C030737  ...  3-indoleacetic acid
# 85086942                        102037  ...  3-indoleacetic acid
# 85165000                    bmse000177  ...  3-indoleacetic acid
# 87571431                         I0022  ...  3-indoleacetic acid
# 134971702                   0000087514  ...  3-indoleacetic acid
# 152199972                       036401  ...  3-indoleacetic acid
# 160969007                         5579  ...  3-indoleacetic acid
# 163806780                    KSC448A7N  ...  3-indoleacetic acid
# 223246660                     SY003464  ...  3-indoleacetic acid
# 223773105  SEOVTRFCIGRIMH-UHFFFAOYSA-N  ...  3-indoleacetic acid
# 250008175  SEOVTRFCIGRIMH-UHFFFAOYSA-N  ...  3-indoleacetic acid
# 252259828                   TRA0099915  ...  3-indoleacetic acid
# 254786070                      87-51-4  ...  3-indoleacetic acid
# 310275201                       GT2044  ...  3-indoleacetic acid
# 312686642                    BIE005703  ...  3-indoleacetic acid
# 315442777                     31095781  ...  3-indoleacetic acid
# 316603474       Intermediates-ZCF08964  ...  3-indoleacetic acid
# 318692595   ToxPlanet-ODctNTEtNDgwMg==  ...  3-indoleacetic acid
# 335988648                      CS-6287  ...  3-indoleacetic acid
# 335988896                     HY-18569  ...  3-indoleacetic acid
# 340540680                      AS20828  ...  3-indoleacetic acid
# 348274310                  HMDB0000197  ...  3-indoleacetic acid
# 382370581                      T2O2791  ...  3-indoleacetic acid
# 405043681                        M9440  ...  3-indoleacetic acid
#
# [32 rows x 5 columns]
#                                 source_id  ...                   Name
# sid                                        ...
# 78908                               14870  ...  3-methylglutaric acid
# 10530728                       4141894834  ...  3-methylglutaric acid
# 49834089                        TL8004224  ...  3-methylglutaric acid
# 74947078                            12284  ...  3-methylglutaric acid
# 85087719                           155556  ...  3-methylglutaric acid
# 85165354                       bmse000575  ...  3-methylglutaric acid
# 87572401                            M0330  ...  3-methylglutaric acid
# 126689711                        49428361  ...  3-methylglutaric acid
# 134978295                      0000626517  ...  3-methylglutaric acid
# 160645891                     CHEBI:68566  ...  3-methylglutaric acid
# 160801820                       ANW-34319  ...  3-methylglutaric acid
# 162295005                     ACMC-209n6p  ...  3-methylglutaric acid
# 162630853                       CTK2F3648  ...  3-methylglutaric acid
# 163693615                        AK129855  ...  3-methylglutaric acid
# 164206616                           69331  ...  3-methylglutaric acid
# 204399201                       TC-123064  ...  3-methylglutaric acid
# 206252937                         VZ35152  ...  3-methylglutaric acid
# 223367517                        EBD12396  ...  3-methylglutaric acid
# 224792756     XJMMNTGIMDZPMU-UHFFFAOYSA-N  ...  3-methylglutaric acid
# 249966823     XJMMNTGIMDZPMU-UHFFFAOYSA-N  ...  3-methylglutaric acid
# 252337051                        MT-38945  ...  3-methylglutaric acid
# 255346472                        Q-101919  ...  3-methylglutaric acid
# 255452604                       AX8034388  ...  3-methylglutaric acid
# 274838713                        J96.141H  ...  3-methylglutaric acid
# 315771938                  DTXSID50211649  ...  3-methylglutaric acid
# 316414235                        AB147315  ...  3-methylglutaric acid
# 316967758                           30015  ...  3-methylglutaric acid
# 318030375                        EBD12396  ...  3-methylglutaric acid
# 318166322                        SC-15126  ...  3-methylglutaric acid
# 319070513  ToxPlanet-NjI2LTUxLTcxMjI4NA==  ...  3-methylglutaric acid
# 322095382                        PI-39477  ...  3-methylglutaric acid
# 341168153              10042184-591836544  ...  3-methylglutaric acid
# 342580537           3-Methylglutaric Acid  ...  3-methylglutaric acid
# 347631345                      LN01742957  ...  3-methylglutaric acid
# 348274782                     HMDB0000752  ...  3-methylglutaric acid
# 350086905                        AE045056  ...  3-methylglutaric acid
# 363602607     XJMMNTGIMDZPMU-UHFFFAOYSA-N  ...  3-methylglutaric acid
# 374247341                        AS-39046  ...  3-methylglutaric acid
# 375200914                      3B3-032859  ...  3-methylglutaric acid
# 375430858                         BD34388  ...  3-methylglutaric acid
# 375685198                        HR135338  ...  3-methylglutaric acid
# 375987104                       HY-113410  ...  3-methylglutaric acid
# 375987355                      CS-0059397  ...  3-methylglutaric acid
# 376262700                         A791966  ...  3-methylglutaric acid
# 381004950                        VL230113  ...  3-methylglutaric acid
# 384653583                        CSN23559  ...  3-methylglutaric acid
# 385675499                       Q27137013  ...  3-methylglutaric acid
# 386512061                       Q27137013  ...  3-methylglutaric acid
# 387174730     XJMMNTGIMDZPMU-UHFFFAOYSA-N  ...  3-methylglutaric acid
# 402302181                     TCM0330-25G  ...  3-methylglutaric acid
# 404757018     XJMMNTGIMDZPMU-UHFFFAOYSA-N  ...  3-methylglutaric acid
# 404841081                        SY049418  ...  3-methylglutaric acid
# 405431413                        MC461252  ...  3-methylglutaric acid
#
# [53 rows x 5 columns]
#                              source_id  ...                       Name
# sid                                     ...
# 5977                            C03079  ...  4-hydroxy-l-glutamic acid
# 8145312                    CHEBI:32811  ...  4-hydroxy-l-glutamic acid
# 250136752  HBDWQSHEVMSFGY-SCQFTWEKSA-N  ...  4-hydroxy-l-glutamic acid
# 312236345                        52072  ...  4-hydroxy-l-glutamic acid
# 385659696                    Q27104231  ...  4-hydroxy-l-glutamic acid
# 386496188                    Q27104231  ...  4-hydroxy-l-glutamic acid
# 348275717                  HMDB0002273  ...  4-hydroxy-l-glutamic acid
#
# [7 rows x 5 columns]
#                                       source_id  ...                        Name
# sid                                              ...
# 49658611                            CHEBI:48430  ...  4-methyl-2-oxovaleric acid
# 85165177                             bmse000383  ...  4-methyl-2-oxovaleric acid
# 87571960                                  K0025  ...  4-methyl-2-oxovaleric acid
# 92298012   FC872D44-3E9A-431D-9F84-6FEF64BFEF19  ...  4-methyl-2-oxovaleric acid
# 126676306                              49414955  ...  4-methyl-2-oxovaleric acid
# 134977374                            0000816660  ...  4-methyl-2-oxovaleric acid
# 160804963                             ANW-37462  ...  4-methyl-2-oxovaleric acid
# 160966373                                  2926  ...  4-methyl-2-oxovaleric acid
# 162296967                           ACMC-209pm0  ...  4-methyl-2-oxovaleric acid
# 162758038                             CTK3I9720  ...  4-methyl-2-oxovaleric acid
# 204390281                            RTR-032363  ...  4-methyl-2-oxovaleric acid
# 204939931                             TR-032363  ...  4-methyl-2-oxovaleric acid
# 206252353                               VZ20257  ...  4-methyl-2-oxovaleric acid
# 223774038           BKAJNAXTPSGJCU-UHFFFAOYSA-N  ...  4-methyl-2-oxovaleric acid
# 249918757           BKAJNAXTPSGJCU-UHFFFAOYSA-N  ...  4-methyl-2-oxovaleric acid
# 251889136                              SC-13856  ...  4-methyl-2-oxovaleric acid
# 252272412                            TRA0100462  ...  4-methyl-2-oxovaleric acid
# 254804832                Intermediates-ZCF04289  ...  4-methyl-2-oxovaleric acid
# 316605351                                  7488  ...  4-methyl-2-oxovaleric acid
# 318692041            ToxPlanet-ODE2LTY2LTA3MA==  ...  4-methyl-2-oxovaleric acid
# 347631264                            LN01742869  ...  4-methyl-2-oxovaleric acid
# 350086811                              AE044939  ...  4-methyl-2-oxovaleric acid
# 363602861           BKAJNAXTPSGJCU-UHFFFAOYSA-N  ...  4-methyl-2-oxovaleric acid
# 383381983                          NSZB-A180966  ...  4-methyl-2-oxovaleric acid
# 387074730           BKAJNAXTPSGJCU-UHFFFAOYSA-N  ...  4-methyl-2-oxovaleric acid
# 404754084           BKAJNAXTPSGJCU-UHFFFAOYSA-N  ...  4-methyl-2-oxovaleric acid
# 404880163                            LQT-B31548  ...  4-methyl-2-oxovaleric acid
#
# [27 rows x 5 columns]

# %% [markdown]
# ## Construct the final dataset used for Dynamic Flux Analysis locally

# %%
name = r'/home/scampit/Data/Expression/Metabolomics/ME1/raw/ME1_Metabolomics.xlsx'
model = r'/home/scampit/Data/CBM/MetabolicModels/RECON1/RECON1.xml'

xl = pd.ExcelFile(name)
sheetNames = xl.sheet_names
sheetNames = sheetNames[1:]

# Create a spreadsheet that will save all of the data
writer = pd.ExcelWriter('ME1_mapped_metabolomics.xlsx', engine='xlsxwriter')

# Parts of the parser that will take a long time, especially if `synmatch` is True
modelMap = mapMetabolicModel(model)
data = queryMetaboAnalyst(filename=name, sheet=sheetNames[0], synmatch=True)
mergedModelDataMap = matchModelAndData(data, modelMap)
PositionModel = mapMetabolitePositionsInModel(mergedModelDataMap, model)
df = constructFinalDataset(PositionModel, name, sheetNames[0])
print(df)

# Save multiple sheets
#for sht in sheetNames:
#    df = constructFinalDataset(PositionModel, name, sht)
#    df.to_excel(writer, sheet_name=sht, index=False)
#    writer.save()
# Out:
# Parsing metabolic model to get metabolite and associated identifiers
# Metabolic map complete
# Mapping metabolomics data to additional identifiers
# Mapping metabolite names to PubChem database for synonym matching and ID retrieval.
